# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation para clasificar (atributo clase discreto) o estimar (atributo clase continuo)

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import math

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import os
import csv

import ipywidgets as widgets
from ipywidgets import Box, Layout
from IPython.display import clear_output
import random

from model.loader import CustomDataset
from model.model import Model
from model.trainer import train_model
from torch.utils.data import DataLoader
from analysis.logger import Logger
from model.LinearClamp import LinearClamp

import torch
import torch.optim as optim
import torch.nn as nn

print("Librerías cargadas")
# Out:
# 2025-11-21 13:48:04.034406: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-21 13:48:04.511492: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-21 13:48:06.761724: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Librerías cargadas

# %% [markdown]
# ## Pre-procesamiento de datos

# %%
# !wget https://raw.githubusercontent.com/juanfra18/TP-IAA/main/datos/Resilience_CleanOnly_v1.csv -O Resilience_CleanOnly_v1.csv
# Out:
# --2025-11-21 13:48:11--  https://raw.githubusercontent.com/juanfra18/TP-IAA/main/datos/Resilience_CleanOnly_v1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1402236 (1,3M) [application/octet-stream]
# Saving to: ‘Resilience_CleanOnly_v1.csv’
#
# Resilience_CleanOnl 100%[===================>]   1,34M  --.-KB/s    in 0,09s
#
# 2025-11-21 13:48:11 (15,5 MB/s) - ‘Resilience_CleanOnly_v1.csv’ saved [1402236/1402236]

# %%
original_data = pd.read_csv('datos/Resilience_CleanOnly_v1.csv', encoding='cp1252', delimiter=',')
original_data.head()
# Out:
#    ppt_internal_id Dataset r8.2_who5_num r8.2_who5_fct4 r8.2_who5_Iexcel  \
# 0                1  Dynata            13           Good            Other
# 1                2  Dynata            21      Very good            Other
# 2                3  Dynata            16           Good            Other
# 3                4  Dynata             4           Poor            Other
# 4                5  Dynata             7           Poor            Other
#
#   age_fct6 gender_fct2         eth_fct4          education_qual  \
# 0    15-24        Male  European/Other^             High school
# 1    55-64        Male  European/Other^  Certificate or diploma
# 2    25-34      Female          Pacific       Bachelor or above
# 3    45-54      Female  European/Other^       Bachelor or above
# 4    15-24      Female  European/Other^  Certificate or diploma
#
#   r4_previnworkforce_fct3  ... r8.16_2_fct2 r8.16_3_fct2 r8.16_6_fct2  \
# 0                Employed  ...           No           No           No
# 1                 Retired  ...           No           No           No
# 2                Employed  ...           No           No          Yes
# 3                Employed  ...          Yes           No           No
# 4                Employed  ...          Yes          Yes          Yes
#
#   r8.16_4_fct2 r12.1_11_fct2 r12.1_13_fct2        r6.4_fct2        r6.5_fct2  \
# 0           No            No           Yes        Low level        Low level
# 1           No           Yes            No  Hazardous level  Hazardous level
# 2           No            No            No        Low level        Low level
# 3          Yes           Yes            No        Low level        Low level
# 4          Yes           Yes           Yes        Low level        Low level
#
#   r6_change_fct3 postweight_unscaled
# 0       Increase         3402.795918
# 1      No change         2250.293478
# 2      No change         1659.857143
# 3       Increase         2132.097087
# 4       Increase         2008.063291
#
# [5 rows x 40 columns]

# %%
original_data
# Out:
#       ppt_internal_id     Dataset r8.2_who5_num r8.2_who5_fct4  \
# 0                   1      Dynata            13           Good
# 1                   2      Dynata            21      Very good
# 2                   3      Dynata            16           Good
# 3                   4      Dynata             4           Poor
# 4                   5      Dynata             7           Poor
# ...               ...         ...           ...            ...
# 3482             3483  Ministries            20      Very good
# 3483             3484  Ministries             6           Poor
# 3484             3485  Ministries             7           Poor
# 3485             3486  Ministries            10           Poor
# 3486             3487  Ministries            19      Very good
#
#      r8.2_who5_Iexcel age_fct6 gender_fct2         eth_fct4  \
# 0               Other    15-24        Male  European/Other^
# 1               Other    55-64        Male  European/Other^
# 2               Other    25-34      Female          Pacific
# 3               Other    45-54      Female  European/Other^
# 4               Other    15-24      Female  European/Other^
# ...               ...      ...         ...              ...
# 3482            Other      65+      Female          Pacific
# 3483            Other    45-54        Male            Maori
# 3484            Other    25-34        Male  European/Other^
# 3485            Other    45-54      Female  European/Other^
# 3486            Other    45-54      Female  European/Other^
#
#                education_qual r4_previnworkforce_fct3  ... r8.16_2_fct2  \
# 0                 High school                Employed  ...           No
# 1      Certificate or diploma                 Retired  ...           No
# 2           Bachelor or above                Employed  ...           No
# 3           Bachelor or above                Employed  ...          Yes
# 4      Certificate or diploma                Employed  ...          Yes
# ...                       ...                     ...  ...          ...
# 3482  No formal qualification                Employed  ...           No
# 3483  No formal qualification                Employed  ...           No
# 3484   Certificate or diploma                Employed  ...           No
# 3485              High school                Employed  ...           No
# 3486        Bachelor or above                Employed  ...           No
#
#      r8.16_3_fct2 r8.16_6_fct2 r8.16_4_fct2 r12.1_11_fct2 r12.1_13_fct2  \
# 0              No           No           No            No           Yes
# 1              No           No           No           Yes            No
# 2              No          Yes           No            No            No
# 3              No           No          Yes           Yes            No
# 4             Yes          Yes          Yes           Yes           Yes
# ...           ...          ...          ...           ...           ...
# 3482           No           No          Yes           Yes           Yes
# 3483           No           No           No            No            No
# 3484          Yes           No          Yes           Yes           Yes
# 3485           No           No           No           Yes            No
# 3486           No           No          Yes            No           Yes
#
#             r6.4_fct2        r6.5_fct2 r6_change_fct3 postweight_unscaled
# 0           Low level        Low level       Increase         3402.795918
# 1     Hazardous level  Hazardous level      No change         2250.293478
# 2           Low level        Low level      No change         1659.857143
# 3           Low level        Low level       Increase         2132.097087
# 4           Low level        Low level       Increase         2008.063291
# ...               ...              ...            ...                 ...
# 3482        Low level        Low level      No change         2661.000000
# 3483        Low level        Low level      No change         2315.666667
# 3484        Low level        Low level      No change         4053.000000
# 3485        Low level        Low level      No change         1557.489362
# 3486        Low level        Low level       Decrease         1557.489362
#
# [3487 rows x 40 columns]

# %%
original_data[['r3.3_fct5','r3.3_num']]
#Prefiero quedarme con r3.3_fct5 ya que es más facil luego encontrar patrones entre los datos si están categorizados y no tienen valores sueltos. sin embargo, la segunda variable no tiene valores nulos mientras que la primera si, asi q la transformo luego

#Quito r3.3_num, r8.2_who5_fct4, r8.2_who5_Iexcel, r3.3_num
#postweight_unscaled no es propiedad real del caso, tal vez pueden usarse como pesos para el entrenamiento¿?
# Out:
#      r3.3_fct5 r3.3_num
# 0          6-9        6
# 1            2        2
# 2          3-5        3
# 3          3-5        4
# 4            1        1
# ...        ...      ...
# 3482         2        2
# 3483       3-5        5
# 3484       3-5        3
# 3485       3-5        3
# 3486         1        1
#
# [3487 rows x 2 columns]

# %%
original_data[['postweight_unscaled']]
# Out:
#       postweight_unscaled
# 0             3402.795918
# 1             2250.293478
# 2             1659.857143
# 3             2132.097087
# 4             2008.063291
# ...                   ...
# 3482          2661.000000
# 3483          2315.666667
# 3484          4053.000000
# 3485          1557.489362
# 3486          1557.489362
#
# [3487 rows x 1 columns]

# %%
rename_col = {
    'r8.2_who5_num': 'target',

    'age_fct6': 'age_group',
    'gender_fct2': 'gender',
    'eth_fct4': 'ethnicity',
    'r4_previnworkforce_fct3': 'employment_pre_lockdown',
    'r4.5_fct3': 'work_type',
    'r7.1_fct3': 'smoking_status',
    'r5.2_fct2': 'self_rated_health',
    'r8.17_fct2': 'mental_health_diagnosis',
    'r5.10': 'physical_disability',
    'r9.1_fct2': 'trauma_exposure',
    'r3.2_fct4': 'bubble_type',
  # 'r3.3_fct5': 'bubble_size_cat',
    'r3.3_num': 'bubble_size_num',
    'r3.7_fct3': 'social_connection_freq',
    'r3.8': 'contact_change',
    'r4_lesswork_fct2': 'less_work',
    'r4_lostwork_fct2': 'lost_work',
    'r5.6_fct3': 'covid_exposure',
    'r3.4': 'bubble_satisfaction',
    'r3.10': 'bubble_relationships',
    'r3.11': 'loneliness',
    'r3.12': 'time_covid_info',
    'r8.16_1_fct2': 'stress_self_health',
    'r8.16_2_fct2': 'stress_family_health',
    'r8.16_3_fct2': 'stress_finances',
    'r8.16_6_fct2': 'stress_employment',
    'r8.16_4_fct2': 'stress_covid_conseq',
    'r12.1_11_fct2': 'positive_lockdown_personal',
    'r12.1_13_fct2': 'positive_lockdown_society',
    'r6.4_fct2': 'alcohol_pre',
    'r6.5_fct2': 'alcohol_during',
    'r6_change_fct3': 'alcohol_change',
}

# %%
data = original_data.copy()

# %%
data = data.drop(columns=['r3.3_fct5', 'r8.2_who5_fct4', 'r8.2_who5_Iexcel','postweight_unscaled','ppt_internal_id','Dataset'])

# %%
data = data.rename(columns = rename_col)

# %%
data.shape
# Out:
# (3487, 34)

# %% [markdown]
# # Missing values

# %% [markdown]
# ## Total missing values

# %%
(data.isnull().sum().sort_values(ascending=False)/len(data))*100
# Out:
# lost_work                     45.081732
# loneliness                    42.299971
# less_work                     39.116719
# work_type                     39.088041
# bubble_relationships          15.256668
# mental_health_diagnosis        2.208202
# social_connection_freq         2.122168
# gender                         0.630915
# contact_change                 0.573559
# positive_lockdown_personal     0.458847
# positive_lockdown_society      0.458847
# income_band                    0.401491
# alcohol_change                 0.229424
# alcohol_during                 0.200746
# alcohol_pre                    0.143390
# bubble_type                    0.114712
# time_covid_info                0.086034
# smoking_status                 0.086034
# employment_pre_lockdown        0.028678
# covid_exposure                 0.028678
# age_group                      0.000000
# target                         0.000000
# education_qual                 0.000000
# ethnicity                      0.000000
# physical_disability            0.000000
# self_rated_health              0.000000
# bubble_size_num                0.000000
# trauma_exposure                0.000000
# bubble_satisfaction            0.000000
# stress_self_health             0.000000
# stress_family_health           0.000000
# stress_covid_conseq            0.000000
# stress_finances                0.000000
# stress_employment              0.000000
# dtype: float64

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# lost_work                     1572
# loneliness                    1475
# less_work                     1364
# work_type                     1363
# bubble_relationships           532
# mental_health_diagnosis         77
# social_connection_freq          74
# gender                          22
# contact_change                  20
# positive_lockdown_personal      16
# positive_lockdown_society       16
# income_band                     14
# alcohol_change                   8
# alcohol_during                   7
# alcohol_pre                      5
# bubble_type                      4
# time_covid_info                  3
# smoking_status                   3
# employment_pre_lockdown          1
# covid_exposure                   1
# age_group                        0
# target                           0
# education_qual                   0
# ethnicity                        0
# physical_disability              0
# self_rated_health                0
# bubble_size_num                  0
# trauma_exposure                  0
# bubble_satisfaction              0
# stress_self_health               0
# stress_family_health             0
# stress_covid_conseq              0
# stress_finances                  0
# stress_employment                0
# dtype: int64

# %% [markdown]
# ## target

# %%
data['target'].value_counts(dropna=False)
# Out:
# target
# 20    337
# 19    274
# 17    236
# 18    223
# 15    219
# 16    207
# 14    198
# 13    182
# 21    150
# 12    143
# 10    142
# 9     132
# 11    128
# 5     125
# 22    102
# 8      98
# 6      97
# 7      92
# 25     85
# 4      70
# 3      62
# 23     62
# 24     54
# 2      24
# .      19
# 1      14
# 0      12
# Name: count, dtype: int64

# %%
# Mantener solo valores numéricos <= 25 y distintos de '.'
col = pd.to_numeric(
    data['target'].astype(str).str.strip().replace({'.': np.nan, '': np.nan}),
    errors='coerce'
)
data = data[col.le(25)].copy()  # descarta NaN y >25
data['target'] = col.loc[data.index].astype('Int64')
data['target'].value_counts(dropna=False)
# Out:
# target
# 20    337
# 19    274
# 17    236
# 18    223
# 15    219
# 16    207
# 14    198
# 13    182
# 21    150
# 12    143
# 10    142
# 9     132
# 11    128
# 5     125
# 22    102
# 8      98
# 6      97
# 7      92
# 25     85
# 4      70
# 3      62
# 23     62
# 24     54
# 2      24
# 1      14
# 0      12
# Name: count, dtype: Int64

# %% [markdown]
# ## employment_pre_lockdown

# %%
table = 'employment_pre_lockdown'
data[table].value_counts(dropna=False)
# Out:
# employment_pre_lockdown
# Employed      2230
# Retired        661
# Unemployed     576
# NaN              1
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# employment_pre_lockdown
# Employed      2231
# Retired        661
# Unemployed     576
# Name: count, dtype: int64

# %% [markdown]
# ## bubble_type

# %%
table = 'bubble_type'
data[table].value_counts(dropna=False)
# Out:
# bubble_type
# With children        1149
# With one adult       1103
# With other adults     685
# Live by myself        527
# NaN                     4
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# bubble_type
# With children        1153
# With one adult       1103
# With other adults     685
# Live by myself        527
# Name: count, dtype: int64

# %% [markdown]
# ## lost_work

# %%
data['lost_work'].value_counts(dropna=False)
# Out:
# lost_work
# Not lost work    1797
# NaN              1559
# Lost work         112
# Name: count, dtype: int64

# %%
(data['employment_pre_lockdown']!='Employed').sum()
#Quienes directamente no tenían trabajo previo al COVID no pueden perderlo
# Out:
# 1237

# %%
data['lost_work'] = np.where(data['lost_work'].isnull() & (data['employment_pre_lockdown']!='Employed'), 'Without work', data['lost_work'])
data['lost_work'].value_counts()
# Out:
# lost_work
# Not lost work    1797
# Without work     1237
# Lost work         112
# Name: count, dtype: int64

# %%
nulos = data['lost_work'].isnull().sum()
print('Porcentaje de nulos: ', (nulos/len(data))*100)
print('Cantidad de nulos: ', nulos)
# Out:
# Porcentaje de nulos:  9.284890426758938
# Cantidad de nulos:  322

# %%
data['lost_work'] = np.where(data['lost_work'].isnull(), 'Not lost work', data['lost_work'])

# %% [markdown]
# ## loneliness

# %%
data[['loneliness']].value_counts()
#Los nulos en realidad corresponden a la categoría 'none'
# Out:
# loneliness
# More than a little    1003
# A little               996
# Name: count, dtype: int64

# %%
data['loneliness'] = np.where(data['loneliness'].isnull(), 'None', data['loneliness'])
data[['loneliness']].value_counts()
# Out:
# loneliness
# None                  1469
# More than a little    1003
# A little               996
# Name: count, dtype: int64

# %% [markdown]
# ## less_work

# %%
#Caso similar a lost_work

# %%
data['less_work'].value_counts()
# Out:
# less_work
# Not less work    1348
# Less work         769
# Name: count, dtype: int64

# %%
data['less_work'] = np.where(data['less_work'].isnull() & (data['employment_pre_lockdown']!='Employed'), 'Without work', data['less_work'])
data['less_work'].value_counts()
# Out:
# less_work
# Not less work    1348
# Without work     1237
# Less work         769
# Name: count, dtype: int64

# %%
nulos = data['less_work'].isnull().sum()
print('Porcentaje de nulos: ', (nulos/len(data))*100)
print('Cantidad de nulos: ', nulos)
# Out:
# Porcentaje de nulos:  3.2871972318339098
# Cantidad de nulos:  114

# %%
data['less_work'] = np.where(data['less_work'].isnull(), 'Not less work', data['less_work'])

# %% [markdown]
# ## work_type

# %%
data['work_type'].value_counts(dropna=False)
# Out:
# work_type
# Not essential worker    1395
# NaN                     1350
# Yes essential worker     723
# Name: count, dtype: int64

# %%
data['work_type'] = np.where(data['work_type'].isnull() & (data['employment_pre_lockdown']!='Employed'), 'Without work', data['work_type'])
data['work_type'].value_counts(dropna=False)
# Out:
# work_type
# Not essential worker    1395
# Without work            1237
# Yes essential worker     723
# NaN                      113
# Name: count, dtype: int64

# %%
nulos = data['work_type'].isnull().sum()
print('Porcentaje de nulos: ', (nulos/len(data))*100)
print('Cantidad de nulos: ', nulos)
# Out:
# Porcentaje de nulos:  3.2583621683967703
# Cantidad de nulos:  113

# %%
data['work_type'] = np.where(data['work_type'].isnull(), 'Not essential worker', data['work_type'])

# %%
data['work_type'].value_counts(dropna=False)
# Out:
# work_type
# Not essential worker    1508
# Without work            1237
# Yes essential worker     723
# Name: count, dtype: int64

# %% [markdown]
# ## bubble_size_num
# Hago que sea 0 cuando no tiene bubble

# %%
data['bubble_size_num'].value_counts(dropna=False)
# Out:
# bubble_size_num
# 2      1176
# 3       617
# 4       574
# 1       527
# 5       320
# 6       118
# 7        56
# 8        26
# 9        15
# .         9
# 10        8
# 12        5
# 13        4
# 11        4
# 25        1
# 14        1
# 19        1
# 40        1
# 21        1
# 45        1
# 999       1
# 15        1
# 70        1
# Name: count, dtype: int64

# %%
# Mantener solo valores numéricos <= 50 y distintos de '.'
col = pd.to_numeric(
    data['bubble_size_num'].astype(str).str.strip().replace({'.': np.nan, '': np.nan}),
    errors='coerce'
)
data = data[col.le(50)].copy()  # descarta NaN y >50
data['bubble_size_num'] = col.loc[data.index].astype('Int64')
data['bubble_size_num'].value_counts(dropna=False)
# Out:
# bubble_size_num
# 2     1176
# 3      617
# 4      574
# 1      527
# 5      320
# 6      118
# 7       56
# 8       26
# 9       15
# 10       8
# 12       5
# 13       4
# 11       4
# 25       1
# 14       1
# 19       1
# 40       1
# 21       1
# 45       1
# 15       1
# Name: count, dtype: Int64

# %% [markdown]
# ## bubble_relationships

# %%
data['bubble_relationships'].value_counts(dropna=False)
# Out:
# bubble_relationships
# Very well    1335
# Well         1114
# NaN           528
# Not well      480
# Name: count, dtype: int64

# %%
# Aquellos que viven solos no van a tener asociado bubble_relationships
len(data[data['bubble_relationships'].isnull() & (data['bubble_type']=='Live by myself')])
# Out:
# 527

# %%
data['bubble_relationships'] = np.where(data['bubble_relationships'].isnull() & (data['bubble_type']=='Live by myself'), 'Without bubble', data['bubble_relationships'])
data['bubble_relationships'].value_counts(dropna=False)
# Out:
# bubble_relationships
# Very well         1335
# Well              1114
# Without bubble     527
# Not well           480
# NaN                  1
# Name: count, dtype: int64

# %%
data['bubble_relationships'] = np.where(data['bubble_relationships'].isnull(), 'Very well', data['bubble_relationships'])
data['bubble_relationships'].value_counts(dropna=False)
# Out:
# bubble_relationships
# Very well         1336
# Well              1114
# Without bubble     527
# Not well           480
# Name: count, dtype: int64

# %% [markdown]
# ## mental_health_diagnosis

# %%
data['mental_health_diagnosis'].value_counts(dropna=False)
# Out:
# mental_health_diagnosis
# No                    2755
# Yes past diagnosis     627
# NaN                     75
# Name: count, dtype: int64

# %%
nulos = data['mental_health_diagnosis'].isnull().sum()
print('Porcentaje de nulos: ', (nulos/len(data))*100)
print('Cantidad de nulos: ', nulos)
# Out:
# Porcentaje de nulos:  2.169511136823836
# Cantidad de nulos:  75

# %%
data['mental_health_diagnosis'] = np.where(data['mental_health_diagnosis'].isnull(), 'No', data['mental_health_diagnosis'])
data['mental_health_diagnosis'].value_counts(dropna=False)
# Out:
# mental_health_diagnosis
# No                    2830
# Yes past diagnosis     627
# Name: count, dtype: int64

# %% [markdown]
# ## social_connection_freq

# %%
data['social_connection_freq'].value_counts(dropna=False)
# Out:
# social_connection_freq
# High      1995
# Medium     944
# Low        447
# NaN         71
# Name: count, dtype: int64

# %%
nulos = data['social_connection_freq'].isnull().sum()
print('Porcentaje de nulos: ', (nulos/len(data))*100)
print('Cantidad de nulos: ', nulos)
# Out:
# Porcentaje de nulos:  2.053803876193231
# Cantidad de nulos:  71

# %%
data['social_connection_freq'] = np.where(data['social_connection_freq'].isnull(), 'High', data['social_connection_freq'])
data['social_connection_freq'].value_counts(dropna=False)
# Out:
# social_connection_freq
# High      2066
# Medium     944
# Low        447
# Name: count, dtype: int64

# %% [markdown]
# ## gender

# %%
data['gender'].value_counts(dropna=False)
# Out:
# gender
# Female    1961
# Male      1474
# NaN         22
# Name: count, dtype: int64

# %%
data['gender'] = np.where(data['gender'].isnull(), 'Female', data['gender'])
data['gender'].value_counts(dropna=False)
# Out:
# gender
# Female    1983
# Male      1474
# Name: count, dtype: int64

# %% [markdown]
# ## contact_change

# %%
data['contact_change'].value_counts(dropna=False)
# Out:
# contact_change
# It has stayed the same    1231
# It has increased          1117
# It has decreased          1091
# NaN                         18
# Name: count, dtype: int64

# %%
data['contact_change'] = np.where(data['contact_change'].isnull(), 'It has stayed the same', data['contact_change'])
data['contact_change'].value_counts(dropna=False)
# Out:
# contact_change
# It has stayed the same    1249
# It has increased          1117
# It has decreased          1091
# Name: count, dtype: int64

# %% [markdown]
# ## positive_lockdown_personal

# %%
data['positive_lockdown_personal'].value_counts(dropna=False)
# Out:
# positive_lockdown_personal
# No     1741
# Yes    1700
# NaN      16
# Name: count, dtype: int64

# %%
data['positive_lockdown_personal'] = np.where(data['positive_lockdown_personal'].isnull(), 'No', data['positive_lockdown_personal'])
data['positive_lockdown_personal'].value_counts(dropna=False)
# Out:
# positive_lockdown_personal
# No     1757
# Yes    1700
# Name: count, dtype: int64

# %% [markdown]
# ## positive_lockdown_society

# %%
data['positive_lockdown_society'].value_counts(dropna=False)
# Out:
# positive_lockdown_society
# No     2003
# Yes    1438
# NaN      16
# Name: count, dtype: int64

# %%
data['positive_lockdown_society'] = np.where(data['positive_lockdown_society'].isnull(), 'No', data['positive_lockdown_society'])
data['positive_lockdown_society'].value_counts(dropna=False)
# Out:
# positive_lockdown_society
# No     2019
# Yes    1438
# Name: count, dtype: int64

# %% [markdown]
# ## income_band

# %%
data['income_band'].value_counts(dropna=False)
# Out:
# income_band
# $30,001– $70,000       1173
# $30,000 or less        1114
# $70,001 – $100,000      432
# Prefer not to say       360
# $100,001 – $150,000     238
# $150,001 or more        126
# NaN                      14
# Name: count, dtype: int64

# %%
most_common = data['income_band'].value_counts(dropna=False).idxmax()
data['income_band'] = np.where(data['income_band'].isnull(), most_common, data['income_band'])
data['income_band'].value_counts(dropna=False)
# Out:
# income_band
# $30,001– $70,000       1187
# $30,000 or less        1114
# $70,001 – $100,000      432
# Prefer not to say       360
# $100,001 – $150,000     238
# $150,001 or more        126
# Name: count, dtype: int64

# %% [markdown]
# ## alcohol_change

# %%
data['alcohol_change'].value_counts(dropna=False)
# Out:
# alcohol_change
# No change    1976
# Increase      870
# Decrease      603
# NaN             8
# Name: count, dtype: int64

# %%
data['alcohol_change'] = np.where(data['alcohol_change'].isnull(), 'No change', data['alcohol_change'])
data['alcohol_change'].value_counts(dropna=False)
# Out:
# alcohol_change
# No change    1984
# Increase      870
# Decrease      603
# Name: count, dtype: int64

# %% [markdown]
# ## alcohol_during

# %%
data['alcohol_during'].value_counts(dropna=False)
# Out:
# alcohol_during
# Low level          3017
# Hazardous level     433
# NaN                   7
# Name: count, dtype: int64

# %%
data['alcohol_during'] = np.where(data['alcohol_during'].isnull(), 'Low level', data['alcohol_during'])
data['alcohol_during'].value_counts(dropna=False)
# Out:
# alcohol_during
# Low level          3024
# Hazardous level     433
# Name: count, dtype: int64

# %% [markdown]
# ## alcohol_pre

# %%
table = 'alcohol_pre'
data[table].value_counts(dropna=False)
# Out:
# alcohol_pre
# Low level          3103
# Hazardous level     349
# NaN                   5
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# alcohol_pre
# Low level          3108
# Hazardous level     349
# Name: count, dtype: int64

# %% [markdown]
# ## time_covid_info

# %%
table = 'time_covid_info'
data[table].value_counts(dropna=False)
# Out:
# time_covid_info
# Less than 2 hours    2975
# Two plus hours        479
# NaN                     3
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# time_covid_info
# Less than 2 hours    2978
# Two plus hours        479
# Name: count, dtype: int64

# %% [markdown]
# ## smoking_status

# %%
table = 'smoking_status'
data[table].value_counts(dropna=False)
# Out:
# smoking_status
# Never      1868
# Past       1043
# Current     543
# NaN           3
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# smoking_status
# Never      1871
# Past       1043
# Current     543
# Name: count, dtype: int64

# %% [markdown]
# ## covid_exposure

# %%
table = 'covid_exposure'
data[table].value_counts(dropna=False)
# Out:
# covid_exposure
# No           3299
# Tested        119
# Suspected      28
# Confirmed      10
# NaN             1
# Name: count, dtype: int64

# %%
most_common = data[table].value_counts(dropna=False).idxmax()
data[table] = np.where(data[table].isnull(), most_common, data[table])
data[table].value_counts(dropna=False)
# Out:
# covid_exposure
# No           3300
# Tested        119
# Suspected      28
# Confirmed      10
# Name: count, dtype: int64

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# target                        0
# age_group                     0
# gender                        0
# ethnicity                     0
# education_qual                0
# employment_pre_lockdown       0
# work_type                     0
# smoking_status                0
# income_band                   0
# self_rated_health             0
# mental_health_diagnosis       0
# physical_disability           0
# trauma_exposure               0
# bubble_type                   0
# bubble_size_num               0
# social_connection_freq        0
# contact_change                0
# less_work                     0
# lost_work                     0
# covid_exposure                0
# bubble_satisfaction           0
# bubble_relationships          0
# loneliness                    0
# time_covid_info               0
# stress_self_health            0
# stress_family_health          0
# stress_finances               0
# stress_employment             0
# stress_covid_conseq           0
# positive_lockdown_personal    0
# positive_lockdown_society     0
# alcohol_pre                   0
# alcohol_during                0
# alcohol_change                0
# dtype: int64

# %%
data
# Out:
#       target age_group  gender        ethnicity           education_qual  \
# 0         13     15-24    Male  European/Other^              High school
# 1         21     55-64    Male  European/Other^   Certificate or diploma
# 2         16     25-34  Female          Pacific        Bachelor or above
# 3          4     45-54  Female  European/Other^        Bachelor or above
# 4          7     15-24  Female  European/Other^   Certificate or diploma
# ...      ...       ...     ...              ...                      ...
# 3482      20       65+  Female          Pacific  No formal qualification
# 3483       6     45-54    Male            Maori  No formal qualification
# 3484       7     25-34    Male  European/Other^   Certificate or diploma
# 3485      10     45-54  Female  European/Other^              High school
# 3486      19     45-54  Female  European/Other^        Bachelor or above
#
#      employment_pre_lockdown             work_type smoking_status  \
# 0                   Employed  Yes essential worker          Never
# 1                    Retired          Without work          Never
# 2                   Employed  Yes essential worker        Current
# 3                   Employed  Yes essential worker          Never
# 4                   Employed  Not essential worker           Past
# ...                      ...                   ...            ...
# 3482                Employed  Not essential worker           Past
# 3483                Employed  Yes essential worker           Past
# 3484                Employed  Not essential worker          Never
# 3485                Employed  Not essential worker          Never
# 3486                Employed  Yes essential worker          Never
#
#               income_band self_rated_health  ... stress_self_health  \
# 0         $30,000 or less    Good or better  ...                 No
# 1      $70,001 – $100,000    Good or better  ...                Yes
# 2        $30,001– $70,000      Poor or Fair  ...                 No
# 3         $30,000 or less    Good or better  ...                 No
# 4        $30,001– $70,000    Good or better  ...                Yes
# ...                   ...               ...  ...                ...
# 3482  $100,001 – $150,000    Good or better  ...                 No
# 3483   $70,001 – $100,000    Good or better  ...                 No
# 3484     $30,001– $70,000    Good or better  ...                 No
# 3485   $70,001 – $100,000    Good or better  ...                 No
# 3486  $100,001 – $150,000    Good or better  ...                 No
#
#      stress_family_health stress_finances stress_employment  \
# 0                      No              No                No
# 1                      No              No                No
# 2                      No              No               Yes
# 3                     Yes              No                No
# 4                     Yes             Yes               Yes
# ...                   ...             ...               ...
# 3482                   No              No                No
# 3483                   No              No                No
# 3484                   No             Yes                No
# 3485                   No              No                No
# 3486                   No              No                No
#
#       stress_covid_conseq positive_lockdown_personal  \
# 0                      No                         No
# 1                      No                        Yes
# 2                      No                         No
# 3                     Yes                        Yes
# 4                     Yes                        Yes
# ...                   ...                        ...
# 3482                  Yes                        Yes
# 3483                   No                         No
# 3484                  Yes                        Yes
# 3485                   No                        Yes
# 3486                  Yes                         No
#
#      positive_lockdown_society      alcohol_pre   alcohol_during  \
# 0                          Yes        Low level        Low level
# 1                           No  Hazardous level  Hazardous level
# 2                           No        Low level        Low level
# 3                           No        Low level        Low level
# 4                          Yes        Low level        Low level
# ...                        ...              ...              ...
# 3482                       Yes        Low level        Low level
# 3483                        No        Low level        Low level
# 3484                       Yes        Low level        Low level
# 3485                        No        Low level        Low level
# 3486                       Yes        Low level        Low level
#
#      alcohol_change
# 0          Increase
# 1         No change
# 2         No change
# 3          Increase
# 4          Increase
# ...             ...
# 3482      No change
# 3483      No change
# 3484      No change
# 3485      No change
# 3486       Decrease
#
# [3457 rows x 34 columns]

# %% [markdown]
# # Normalización de datos:

# %%
data.head()
# Out:
#    target age_group  gender        ethnicity          education_qual  \
# 0      13     15-24    Male  European/Other^             High school
# 1      21     55-64    Male  European/Other^  Certificate or diploma
# 2      16     25-34  Female          Pacific       Bachelor or above
# 3       4     45-54  Female  European/Other^       Bachelor or above
# 4       7     15-24  Female  European/Other^  Certificate or diploma
#
#   employment_pre_lockdown             work_type smoking_status  \
# 0                Employed  Yes essential worker          Never
# 1                 Retired          Without work          Never
# 2                Employed  Yes essential worker        Current
# 3                Employed  Yes essential worker          Never
# 4                Employed  Not essential worker           Past
#
#           income_band self_rated_health  ... stress_self_health  \
# 0     $30,000 or less    Good or better  ...                 No
# 1  $70,001 – $100,000    Good or better  ...                Yes
# 2    $30,001– $70,000      Poor or Fair  ...                 No
# 3     $30,000 or less    Good or better  ...                 No
# 4    $30,001– $70,000    Good or better  ...                Yes
#
#   stress_family_health stress_finances stress_employment  stress_covid_conseq  \
# 0                   No              No                No                   No
# 1                   No              No                No                   No
# 2                   No              No               Yes                   No
# 3                  Yes              No                No                  Yes
# 4                  Yes             Yes               Yes                  Yes
#
#   positive_lockdown_personal positive_lockdown_society      alcohol_pre  \
# 0                         No                       Yes        Low level
# 1                        Yes                        No  Hazardous level
# 2                         No                        No        Low level
# 3                        Yes                        No        Low level
# 4                        Yes                       Yes        Low level
#
#     alcohol_during alcohol_change
# 0        Low level       Increase
# 1  Hazardous level      No change
# 2        Low level      No change
# 3        Low level       Increase
# 4        Low level       Increase
#
# [5 rows x 34 columns]

# %%
# Primero paso las columnas categóricas a números
mapping = {
        "age_group": {
            "15-24": 0,
            "25-34": 1,
            "35-44": 2,
            "45-54": 3,
            "55-64": 4,
            "65+": 5
        },
        "gender": {
            "Male": 0,
            "Female": 1
        },
        "ethnicity": {
            "European/Other^": 0,
            "Maori": 1,
            "Pacific": 2,
            "Asian": 3
        },
        "education_qual": {
            "No formal qualification": 0,
            "High school": 1,
            "Certificate or diploma": 2,
            "Bachelor or above": 3
        },
        "employment_pre_lockdown": {
            "Employed": 0,
            "Unemployed": 1,
            "Retired": 2
        },
        "work_type": {
            "Not essential worker": 0,
            "Yes essential worker": 1,
            "Without work": 2
        },
        "smoking_status": {
            "Never": 0,
            "Past": 1,
            "Current": 2
        },
        "income_band": {
            "$30,000 or less": 0,
            "$30,001– $70,000": 1,
            "$70,001 – $100,000": 2,
            "$100,001 – $150,000": 3,
            "$150,001 or more": 4,
            "Prefer not to say": 5
        },
        "self_rated_health": {
            "Poor or Fair": 0,
            "Good or better": 1
        },
        "mental_health_diagnosis": {
            "No": 0,
            "Yes past diagnosis": 1
        },
        "physical_disability": {
            "No": 0,
            "Yes": 1
        },
        "trauma_exposure": {
            "No": 0,
            "Yes": 1
        },
        "bubble_type": {
            "Live by myself": 0,
            "With one adult": 1,
            "With other adults": 2,
            "With children": 3
        },
        "social_connection_freq": {
            "High": 2,
            "Medium": 1,
            "Low": 0
        },
        "contact_change": {
            "It has stayed the same": 0,
            "It has increased": 1,
            "It has decreased": 2
        },
        "less_work": {
            "Not less work": 0,
            "Less work": 1,
            "Without work": 2
        },
        "lost_work": {
            "Not lost work": 0,
            "Lost work": 1,
            "Without work": 2
        },
        "covid_exposure": {
            "No": 0,
            "Suspected": 1,
            "Tested": 2,
            "Confirmed": 3
        },
        "bubble_satisfaction": {
            "Not satifisfied": 0,
            "Satisfied": 1,
            "Extremely satisfied": 2
        },
        "bubble_relationships": {
            "Not well": 0,
            "Well": 1,
            "Very well": 2,
            "Without bubble": 3
        },
        "loneliness": {
            "None": 0,
            "A little": 1,
            "More than a little": 2
        },
        "time_covid_info": {
            "Less than 2 hours": 0,
            "Two plus hours": 1
        },
        "stress_self_health": {
            "No": 0,
            "Yes": 1
        },
        "stress_family_health": {
            "No": 0,
            "Yes": 1
        },
        "stress_finances": {
            "No": 0,
            "Yes": 1
        },
        "stress_employment": {
            "No": 0,
            "Yes": 1
        },
        "stress_covid_conseq": {
            "No": 0,
            "Yes": 1
        },
        "positive_lockdown_personal": {
            "No": 0,
            "Yes": 1
        },
        "positive_lockdown_society": {
            "No": 0,
            "Yes": 1
        },
        "alcohol_pre": {
            "Low level": 0,
            "Hazardous level": 1
        },
        "alcohol_during": {
            "Low level": 0,
            "Hazardous level": 1
        },
        "alcohol_change": {
            "No change": 2,
            "Increase": 1,
            "Decrease": 0
        }
}

# %%
data_encoded = data.copy()

# 1) Reemplaza
data_encoded = data_encoded.replace(mapping)

# 2) Fuerza tipo numérico en las columnas mapeadas
for col, m in mapping.items():
    if col not in data_encoded.columns:
        continue
    if isinstance(m, dict) and len(m) == 0:
        # casos numéricos no codificados
        data_encoded[col] = pd.to_numeric(data_encoded[col], errors="coerce")
    elif isinstance(m, dict) and len(m) > 0:
        # columnas categóricas codificadas -> a enteros con soporte de NaN
        data_encoded[col] = pd.to_numeric(data_encoded[col], errors="coerce").astype("Int64")

# 3) (Opcional) chequeo de valores no mapeados
unmapped_report = {}
for col, m in mapping.items():
    if col in data.columns and isinstance(m, dict) and len(m) > 0:
        mask_unmapped = data[col].notna() & ~data[col].isin(m.keys())
        if mask_unmapped.any():
            unmapped_report[col] = sorted(data.loc[mask_unmapped, col].unique().tolist())

if unmapped_report:
    print("Categorías no mapeadas detectadas:", unmapped_report)
# Out:
# /tmp/ipykernel_553995/940831558.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_encoded = data_encoded.replace(mapping)

# %%
data_encoded
# Out:
#       target  age_group  gender  ethnicity  education_qual  \
# 0         13          0       0          0               1
# 1         21          4       0          0               2
# 2         16          1       1          2               3
# 3          4          3       1          0               3
# 4          7          0       1          0               2
# ...      ...        ...     ...        ...             ...
# 3482      20          5       1          2               0
# 3483       6          3       0          1               0
# 3484       7          1       0          0               2
# 3485      10          3       1          0               1
# 3486      19          3       1          0               3
#
#       employment_pre_lockdown  work_type  smoking_status  income_band  \
# 0                           0          1               0            0
# 1                           2          2               0            2
# 2                           0          1               2            1
# 3                           0          1               0            0
# 4                           0          0               1            1
# ...                       ...        ...             ...          ...
# 3482                        0          0               1            3
# 3483                        0          1               1            2
# 3484                        0          0               0            1
# 3485                        0          0               0            2
# 3486                        0          1               0            3
#
#       self_rated_health  ...  stress_self_health  stress_family_health  \
# 0                     1  ...                   0                     0
# 1                     1  ...                   1                     0
# 2                     0  ...                   0                     0
# 3                     1  ...                   0                     1
# 4                     1  ...                   1                     1
# ...                 ...  ...                 ...                   ...
# 3482                  1  ...                   0                     0
# 3483                  1  ...                   0                     0
# 3484                  1  ...                   0                     0
# 3485                  1  ...                   0                     0
# 3486                  1  ...                   0                     0
#
#       stress_finances  stress_employment  stress_covid_conseq  \
# 0                   0                  0                    0
# 1                   0                  0                    0
# 2                   0                  1                    0
# 3                   0                  0                    1
# 4                   1                  1                    1
# ...               ...                ...                  ...
# 3482                0                  0                    1
# 3483                0                  0                    0
# 3484                1                  0                    1
# 3485                0                  0                    0
# 3486                0                  0                    1
#
#       positive_lockdown_personal  positive_lockdown_society  alcohol_pre  \
# 0                              0                          1            0
# 1                              1                          0            1
# 2                              0                          0            0
# 3                              1                          0            0
# 4                              1                          1            0
# ...                          ...                        ...          ...
# 3482                           1                          1            0
# 3483                           0                          0            0
# 3484                           1                          1            0
# 3485                           1                          0            0
# 3486                           0                          1            0
#
#       alcohol_during  alcohol_change
# 0                  0               1
# 1                  1               2
# 2                  0               2
# 3                  0               1
# 4                  0               1
# ...              ...             ...
# 3482               0               2
# 3483               0               2
# 3484               0               2
# 3485               0               2
# 3486               0               0
#
# [3457 rows x 34 columns]

# %%
data_encoded.to_csv('datos/Resilience_CleanOnly_v1_PREPROCESSED_v2.csv', index=False)

# %% [markdown]
# # Definir y entrenar el modelo

# %%
#train_data = CustomDataset(train_df, feat_cols, 'target', scaler_X, scaler_y)
#val_data   = CustomDataset(val_df,   feat_cols, 'target', scaler_X, scaler_y)

#train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
#val_loader   = DataLoader(val_data, batch_size=256, shuffle=False)

# %%
df = pd.read_csv("datos/Resilience_CleanOnly_v1_PREPROCESSED_v2.csv", encoding="latin1")
sizes = [len(df.columns)-1,16,1]
output_activation = nn.Identity
intermediate_activation = nn.ReLU
normalize_output = True
loss = nn.MSELoss
name = f"model_{sizes}_output_{output_activation.__name__}_intermediate_{intermediate_activation.__name__}_normalized_data_{normalize_output}_loss_{loss.__name__}"

comparison_table = pd.read_csv("results/comparison_table.csv")

#probabilities = df["weight"]


weight_path = f"results/{name}.pth" if os.path.exists(f"results/{name}.pth") else None
logger = Logger("results/logs")

train_df = df.sample(frac=0.7, random_state=42)
val_df = df.drop(train_df.index)

train_data = CustomDataset(train_df, normalize_output)
val_data = CustomDataset(val_df, normalize_output)
train_loader = DataLoader(train_data, batch_size=2, shuffle=True)
val_loader = DataLoader(val_data, batch_size=2, shuffle=False)

model = Model(weight_path,description=name, hidden_sizes=sizes, output_activation=output_activation, dropout_p=0.5)  
criterion = loss()
optimizer = optim.Adagrad(model.parameters(), lr=0.01)

trained_model, val_loss = train_model(model, train_loader, val_loader, criterion, optimizer, 300, logger)

torch.save(trained_model.state_dict(), f"results/{name}.pth")

new_row = {
    "name": name,
    "loss": val_loss
}

comparison_table = pd.concat([comparison_table, pd.DataFrame([new_row])], ignore_index=True)
comparison_table.to_csv("results/comparison_table.csv", index=False)
# Out:
# [[2025-11-21 13:48:13]] Starting training on model: model_[33, 16, 1]_output_Identity_intermediate_ReLU_normalized_data_True_loss_MSELoss
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:16]] Epoch 1/300, Train Loss: 0.03905633, Val Loss: 0.03317616
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:18]] Epoch 2/300, Train Loss: 0.03205837, Val Loss: 0.03249302
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:21]] Epoch 3/300, Train Loss: 0.03085531, Val Loss: 0.03209731
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:24]] Epoch 4/300, Train Loss: 0.03034324, Val Loss: 0.03205895
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:26]] Epoch 5/300, Train Loss: 0.02983339, Val Loss: 0.03189542
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:28]] Epoch 6/300, Train Loss: 0.02956775, Val Loss: 0.03190273
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:31]] Epoch 7/300, Train Loss: 0.02938166, Val Loss: 0.03200326
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:33]] Epoch 8/300, Train Loss: 0.02909890, Val Loss: 0.03188124
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:36]] Epoch 9/300, Train Loss: 0.02891744, Val Loss: 0.03221641
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:38]] Epoch 10/300, Train Loss: 0.02882406, Val Loss: 0.03198456
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:42]] Epoch 11/300, Train Loss: 0.02864275, Val Loss: 0.03164406
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:44]] Epoch 12/300, Train Loss: 0.02853879, Val Loss: 0.03162953
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:47]] Epoch 13/300, Train Loss: 0.02842821, Val Loss: 0.03154730
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:49]] Epoch 14/300, Train Loss: 0.02829769, Val Loss: 0.03182611
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:52]] Epoch 15/300, Train Loss: 0.02820129, Val Loss: 0.03205098
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:55]] Epoch 16/300, Train Loss: 0.02807648, Val Loss: 0.03160031
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:48:57]] Epoch 17/300, Train Loss: 0.02799543, Val Loss: 0.03150879
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:00]] Epoch 18/300, Train Loss: 0.02790752, Val Loss: 0.03146980
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:03]] Epoch 19/300, Train Loss: 0.02779505, Val Loss: 0.03145819
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:05]] Epoch 20/300, Train Loss: 0.02764294, Val Loss: 0.03152264
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:08]] Epoch 21/300, Train Loss: 0.02763823, Val Loss: 0.03161096
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:11]] Epoch 22/300, Train Loss: 0.02755431, Val Loss: 0.03141593
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:14]] Epoch 23/300, Train Loss: 0.02751529, Val Loss: 0.03151901
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:17]] Epoch 24/300, Train Loss: 0.02745543, Val Loss: 0.03142751
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:19]] Epoch 25/300, Train Loss: 0.02739577, Val Loss: 0.03142561
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:22]] Epoch 26/300, Train Loss: 0.02732851, Val Loss: 0.03143764
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:24]] Epoch 27/300, Train Loss: 0.02728058, Val Loss: 0.03187375
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:26]] Epoch 28/300, Train Loss: 0.02726125, Val Loss: 0.03141690
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:28]] Epoch 29/300, Train Loss: 0.02721364, Val Loss: 0.03156593
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:30]] Epoch 30/300, Train Loss: 0.02714159, Val Loss: 0.03140343
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:32]] Epoch 31/300, Train Loss: 0.02711600, Val Loss: 0.03138944
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:34]] Epoch 32/300, Train Loss: 0.02702598, Val Loss: 0.03152748
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:36]] Epoch 33/300, Train Loss: 0.02701391, Val Loss: 0.03152632
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:38]] Epoch 34/300, Train Loss: 0.02693478, Val Loss: 0.03146604
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:40]] Epoch 35/300, Train Loss: 0.02689442, Val Loss: 0.03189496
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:42]] Epoch 36/300, Train Loss: 0.02687438, Val Loss: 0.03146486
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:44]] Epoch 37/300, Train Loss: 0.02685383, Val Loss: 0.03165585
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:46]] Epoch 38/300, Train Loss: 0.02677136, Val Loss: 0.03157106
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:48]] Epoch 39/300, Train Loss: 0.02675193, Val Loss: 0.03140122
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:50]] Epoch 40/300, Train Loss: 0.02668710, Val Loss: 0.03167969
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:52]] Epoch 41/300, Train Loss: 0.02669813, Val Loss: 0.03145444
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:54]] Epoch 42/300, Train Loss: 0.02663827, Val Loss: 0.03159909
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:56]] Epoch 43/300, Train Loss: 0.02664022, Val Loss: 0.03166187
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:49:58]] Epoch 44/300, Train Loss: 0.02659031, Val Loss: 0.03145749
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:00]] Epoch 45/300, Train Loss: 0.02659679, Val Loss: 0.03147513
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:05]] Epoch 46/300, Train Loss: 0.02654638, Val Loss: 0.03150902
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:08]] Epoch 47/300, Train Loss: 0.02652274, Val Loss: 0.03150460
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:10]] Epoch 48/300, Train Loss: 0.02651558, Val Loss: 0.03150834
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:12]] Epoch 49/300, Train Loss: 0.02648146, Val Loss: 0.03159100
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:15]] Epoch 50/300, Train Loss: 0.02644468, Val Loss: 0.03150236
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:17]] Epoch 51/300, Train Loss: 0.02644523, Val Loss: 0.03156130
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:19]] Epoch 52/300, Train Loss: 0.02641194, Val Loss: 0.03169018
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:21]] Epoch 53/300, Train Loss: 0.02639017, Val Loss: 0.03156367
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:23]] Epoch 54/300, Train Loss: 0.02631343, Val Loss: 0.03208528
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:25]] Epoch 55/300, Train Loss: 0.02635248, Val Loss: 0.03167444
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:27]] Epoch 56/300, Train Loss: 0.02632677, Val Loss: 0.03161673
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:29]] Epoch 57/300, Train Loss: 0.02627985, Val Loss: 0.03156259
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:31]] Epoch 58/300, Train Loss: 0.02626889, Val Loss: 0.03187071
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:33]] Epoch 59/300, Train Loss: 0.02623892, Val Loss: 0.03174649
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:35]] Epoch 60/300, Train Loss: 0.02620392, Val Loss: 0.03172594
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:37]] Epoch 61/300, Train Loss: 0.02622558, Val Loss: 0.03158315
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:39]] Epoch 62/300, Train Loss: 0.02612551, Val Loss: 0.03158543
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:41]] Epoch 63/300, Train Loss: 0.02615863, Val Loss: 0.03160127
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:43]] Epoch 64/300, Train Loss: 0.02614271, Val Loss: 0.03158821
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:45]] Epoch 65/300, Train Loss: 0.02609992, Val Loss: 0.03165326
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:47]] Epoch 66/300, Train Loss: 0.02605329, Val Loss: 0.03167324
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:49]] Epoch 67/300, Train Loss: 0.02607557, Val Loss: 0.03165034
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:52]] Epoch 68/300, Train Loss: 0.02608131, Val Loss: 0.03181766
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:54]] Epoch 69/300, Train Loss: 0.02605156, Val Loss: 0.03173811
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:56]] Epoch 70/300, Train Loss: 0.02602388, Val Loss: 0.03180163
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:50:58]] Epoch 71/300, Train Loss: 0.02602097, Val Loss: 0.03172824
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:00]] Epoch 72/300, Train Loss: 0.02600988, Val Loss: 0.03186410
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:02]] Epoch 73/300, Train Loss: 0.02595507, Val Loss: 0.03163667
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:04]] Epoch 74/300, Train Loss: 0.02598681, Val Loss: 0.03167373
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:07]] Epoch 75/300, Train Loss: 0.02594749, Val Loss: 0.03176737
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:09]] Epoch 76/300, Train Loss: 0.02593999, Val Loss: 0.03168315
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:11]] Epoch 77/300, Train Loss: 0.02593185, Val Loss: 0.03179980
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:13]] Epoch 78/300, Train Loss: 0.02589494, Val Loss: 0.03186643
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:16]] Epoch 79/300, Train Loss: 0.02588109, Val Loss: 0.03185129
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:18]] Epoch 80/300, Train Loss: 0.02586119, Val Loss: 0.03173206
# /home/juan/Apps/miniconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:616: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [[2025-11-21 13:51:20]] Epoch 81/300, Train Loss: 0.02586280, Val Loss: 0.03177347
# [[2025-11-21 13:51:20]] Early stopping at epoch 81/300
# Training complete
